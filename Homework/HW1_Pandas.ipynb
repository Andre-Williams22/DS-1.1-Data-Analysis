# %% [markdown]
# ## Write Custom Function to Compute Histogram for a Numerical Array
#
# - You can use numpy
#
# - Your function takes two arguments: 1- list 2- interval
#
# - Your function would return a dictionary with intervals as keys and how many of elements in list are in the intervals as values

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../Notebooks/datasets/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# histogram function

def custom_hist(ls, interval):
    hist_ls_dict = dict()
    min_ls = np.min(ls)
    max_ls = np.max(ls)
    I = np.ceil((max_ls - min_ls) / interval)
    for j in range(interval):
        hist_ls_dict[j]= interval     
    return hist_ls_dict
        
print(custom_hist(df['Age'].dropna().values, 16))
# Out:
# {0: 16, 1: 16, 2: 16, 3: 16, 4: 16, 5: 16, 6: 16, 7: 16, 8: 16, 9: 16, 10: 16, 11: 16, 12: 16, 13: 16, 14: 16, 15: 16}

# %% [markdown]
# ## For visualization part, you should elaborate on the following

# %%
import matplotlib.pyplot as plt

#hist_dict = custom_hist(df['Age'].dropna().values, 16)
pd.DataFrame([custom_hist(df['Age'].dropna().values, 16)]).plot.hist(grid=True, bins=20, rwidth=.9)
#plt.bar(hist_dict.keys(), hist_dict.values())

# %% [markdown]
# ## Q2: How we can plot histogram of Age for female and male with legend?

# %% [markdown]
# Use Pandas with .groupby method and plot the following

# %%
df.groupby('Sex')['Age'].plot(bins=16, kind='hist', legend=True, alpha=.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df.groupby('Sex')['Age'].plot(bins=20, kind='hist', legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
female = df[df['Sex'] == 'female']
male = df[df['Sex'] == 'male']

# %%
def custom_histo(female):
    hashtable = {}
    
    for item in female:
        if item in female:
            hashtable[item] += 1
        else:
            hashtable[item] = 1
    return pd.DataFrame([hashtable]).plot.hist(grid=True, bins=20, rwidth=.9)
print(custom_histo(df[df['Sex'].str.contains('Female') & df['Age']].count()))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import seaborn as sns
df.groupby(['Sex'])['Age'].value_counts().unstack().plot(kind='hist',stacked=True,figsize=(20,20))

# %%
import seaborn as sns
sns.countplot(x="Sex", hue="Age", data=df)

# %%
sns.distplot(df['Age'], bins=30, kde=False)

# %%
df.groupby('Sex')['Age'].value_counts().head(200).plot(kind='barh', figsize=(20,10))

# %%
df.groupby(['Sex', 'Age']).count().Name.plot(kind='hist')

# %%
sns.distplot(df['Age'].values, kde=False, bins=20) # histogram

# %%
df['Sex'].value_counts('Age').plot(kind='bar')

# %%
sns.countplot(x="Sex", palette="spring", data=df)

# %%
df.groupby('Sex')['Age'].hist(bins=20)
plt.title('My title')
plt.xlabel('Age')
plt.ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')
